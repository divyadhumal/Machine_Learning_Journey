# %%
import pandas as pd
 
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score

import matplotlib.pyplot as plt

# %%
#load the data
data = load_diabetes()
X = data.data
y = (data.target > 140).astype(int)#make it binary:1 if target >140 else 0

print(X.shape, y.shape)
# Out:
# (442, 10) (442,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state =42)

# %%
gbm_clf = GradientBoostingClassifier(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=3,
    subsample=0.8,
    random_state =42
)

# %%
#fit the model
gbm_clf.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=42, subsample=0.8)

# %%
#make prediction on test data
prediction = gbm_clf.predict(X_test)

# %%
#check accuracy

acc= accuracy_score(y_test, prediction)
print("Accuracy on test data:", acc)
# Out:
# Accuracy on test data: 0.7969924812030075

# %%
train_errors =[]
test_errors =[]

for n in range(1,201):
    gbm = GradientBoostingClassifier(
        n_estimators =n,
        learning_rate=0.1,
        max_depth=3,
        subsample =0.8,
        random_state =42
    )
    gbm.fit(X_train, y_train)

    #Training error
    train_pred = gbm.predict(X_train)
    train_error = 1 - accuracy_score(y_train, train_pred)
    train_errors.append(train_error)

    #Testing error
    test_pred = gbm.predict(X_test)
    test_error = 1- accuracy_score(y_test, test_pred)
    test_errors.append(test_error)

plt.plot(range(1,201), train_errors, label = "Train Error")
plt.plot(range(1,201), test_errors, label="Test Error")
plt.xlabel("Number of Trees")
plt.ylabel("Error")
plt.title("GBM: Training vs Test Error")
plt.legend()
plt.show()
