# %%
import pandas as pd
file_path =r"C:\Users\DIVYA\Downloads\WA_Fn-UseC_-Telco-Customer-Churn.csv"
df = pd.read_csv(file_path)

# %%
data.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 data.info()
#
# NameError: name 'data' is not defined

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ## Data Cleaning and Processing

# %%
#check for missing values
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.dtypes
# Out:
# customerID              str
# gender                  str
# SeniorCitizen         int64
# Partner                 str
# Dependents              str
# tenure                int64
# PhoneService            str
# MultipleLines           str
# InternetService         str
# OnlineSecurity          str
# OnlineBackup            str
# DeviceProtection        str
# TechSupport             str
# StreamingTV             str
# StreamingMovies         str
# Contract                str
# PaperlessBilling        str
# PaymentMethod           str
# MonthlyCharges      float64
# TotalCharges            str
# Churn                   str
# dtype: object

# %%
#convert 'TotalCharges' to numeric and see if they are any errors
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

#check again for missing values again
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
#remove rows with missing 'TotalCharges' (small number of rows, so safe to drop)
df_cleaned = df.dropna(subset=['TotalCharges'])

#check again for missing values
df_cleaned.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='str')

# %% [markdown]
# ## Converting Categorical Columns to Numbers

# %%
from sklearn.preprocessing import LabelEncoder

#Make a copy of the cleaned data to work with
df_encoded = df_cleaned.copy()

#create label encoder object
le =LabelEncoder()

#List od columns to encode
categorical_cols = ['gender', 'Partner','Dependents','PhoneService','MultipleLines','InternetService','OnlineSecurity',
                    'OnlineBackup', 'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','Contract','PaperlessBilling','PaymentMethod','Churn']

#Apply label encoding each of these columns
for col in categorical_cols:
    df_encoded[col] = le.fit_transform(df_encoded[col])

#show the first few rows to confirm encoding
df_encoded.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG       0              0        1           0       1
# 1  5575-GNVDE       1              0        0           0      34
# 2  3668-QPYBK       1              0        0           0       2
# 3  7795-CFOCW       1              0        0           0      45
# 4  9237-HQITU       0              0        0           0       2
#
#    PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0             0              1                0               0  ...
# 1             1              0                0               2  ...
# 2             1              0                0               2  ...
# 3             0              1                0               2  ...
# 4             1              0                1               0  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %% [markdown]
# ### Splitting the data in to Features(X) and Target(y)

# %%
#Features (X) - all columns except 'Churn'
X =df_encoded.drop('Churn', axis =1)

#Target (y) - only the 'Churn' column
y = df_encoded["Churn"]

# %% [markdown]
# ### Building the Decision Tree Classifier

# %%
#Remove 'customerID' frim features(It's not useful for prediction)
X = df_encoded.drop(['customerID', 'Churn'], axis =1)

#Target variable(Churn)
y = df_encoded['Churn']

from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier()

#fit the tree (train the model)
tree.fit(X, y)
tree
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ### Visualizing the Decision Tree to See How it Makes Decision

# %%
from sklearn import tree as sktree
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
sktree.plot_tree(tree, filled=True, feature_names = X.columns, class_names= ['No', 'Yes'])
plt.show()

# %%
#Rebuld the tree with a smaller max_depth to make it simpler and easier to visualize
tree = DecisionTreeClassifier(max_depth=3, random_state=42)
tree.fit(X,y)

#Visualize the simpler decision tree again
plt.figure(figsize=(20, 10))
sktree.plot_tree(tree, filled=True, feature_names = X.columns, class_names=['No','Yes'])
plt.show()

# %% [markdown]
# ### Evaluating the Decision Tree(Model Accuracy)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y , test_size =0.3, random_state=42)

# %%
tree= DecisionTreeClassifier(max_depth =3, random_state =42)
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

y_pred = tree.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:" ,recall)
# Out:
# Accuracy: 0.7772511848341233
# Precision: 0.6531986531986532
# Recall: 0.34581105169340465

# %% [markdown]
# ### Using the Decision Tree for New Predictions

# %%
new_customer ={
    'gender':1,
    'SeniorCitizen':0,
    'Partner':1,
    'Dependents':0,
    'tenure':12,
    'PhoneService':1,
    'MultipleLines':0,
    'InternetService':1,
    'OnlineSecurity':0,
    'OnlineBackup':1,
    'DeviceProtection':1,
    'TechSupport':0,
    'StreamingTV':0,
    'StreamingMovies':1,
    'Contract':0,
    'PaperlessBilling':1,
    'PaymentMethod':2,
    'MonthlyCharges':75.5,
    'TotalCharges':500.0


}

# %%
new_data = pd.DataFrame([new_customer])

prediction = tree.predict(new_data)
probability = tree.predict_proba(new_data)

print("Prediction (0=No Churn, 1= Churn):", prediction[0])
print("Probability of churn:", probability[0][1])
# Out:
# Prediction (0=No Churn, 1= Churn): 1
# Probability of churn: 0.6965811965811965
